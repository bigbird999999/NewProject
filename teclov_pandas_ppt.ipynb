# %% [markdown]
# <a href="https://colab.research.google.com/github/bigbird999999/NewProject/blob/main/teclov_pandas_ppt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # create Pandas Series

# %%
import pandas as pd

# %%
a = pd.Series([1,2,3,4,5])

# %%
a
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
type(a)
# Out:
# pandas.core.series.Series

# %%
a[2]
# Out:
# np.int64(3)

# %%
a = pd.Series(['a','b','c'])

# %%
a
# Out:
# 0    a
# 1    b
# 2    c
# dtype: object

# %%
a = pd.date_range(start = '01-01-2018', end = '23-5-2018')

# %%
a
# Out:
# DatetimeIndex(['2018-01-01', '2018-01-02', '2018-01-03', '2018-01-04',
#                '2018-01-05', '2018-01-06', '2018-01-07', '2018-01-08',
#                '2018-01-09', '2018-01-10',
#                ...
#                '2018-05-14', '2018-05-15', '2018-05-16', '2018-05-17',
#                '2018-05-18', '2018-05-19', '2018-05-20', '2018-05-21',
#                '2018-05-22', '2018-05-23'],
#               dtype='datetime64[ns]', length=143, freq='D')

# %%
type(a)
# Out:
# pandas.core.indexes.datetimes.DatetimeIndex

# %% [markdown]
# # Pandas dataframe

# %%
import numpy as np

# %%
temp = np.random.randint(low = 20, high =100, size = [20,])
name = np.random.choice(['Abhay','Teclov','Geekshub','Ankit'],20)
random = np.random.choice([10,11,13,12,14],20)

# %%
temp
# Out:
# array([28, 43, 67, 76, 80, 91, 90, 61, 71, 29, 40, 66, 91, 90, 46, 41, 48,
#        40, 35, 73])

# %%
name
# Out:
# array(['Ankit', 'Ankit', 'Geekshub', 'Abhay', 'Geekshub', 'Abhay',
#        'Geekshub', 'Abhay', 'Abhay', 'Ankit', 'Abhay', 'Teclov', 'Abhay',
#        'Abhay', 'Geekshub', 'Abhay', 'Teclov', 'Ankit', 'Ankit', 'Teclov'],
#       dtype='<U8')

# %%
random
# Out:
# array([12, 10, 14, 11, 10, 12, 12, 10, 14, 13, 11, 10, 10, 10, 13, 12, 13,
#        11, 11, 10])

# %%
a = list(zip(temp, name, random))
a
# Out:
# [(np.int64(28), np.str_('Ankit'), np.int64(12)),
#  (np.int64(43), np.str_('Ankit'), np.int64(10)),
#  (np.int64(67), np.str_('Geekshub'), np.int64(14)),
#  (np.int64(76), np.str_('Abhay'), np.int64(11)),
#  (np.int64(80), np.str_('Geekshub'), np.int64(10)),
#  (np.int64(91), np.str_('Abhay'), np.int64(12)),
#  (np.int64(90), np.str_('Geekshub'), np.int64(12)),
#  (np.int64(61), np.str_('Abhay'), np.int64(10)),
#  (np.int64(71), np.str_('Abhay'), np.int64(14)),
#  (np.int64(29), np.str_('Ankit'), np.int64(13)),
#  (np.int64(40), np.str_('Abhay'), np.int64(11)),
#  (np.int64(66), np.str_('Teclov'), np.int64(10)),
#  (np.int64(91), np.str_('Abhay'), np.int64(10)),
#  (np.int64(90), np.str_('Abhay'), np.int64(10)),
#  (np.int64(46), np.str_('Geekshub'), np.int64(13)),
#  (np.int64(41), np.str_('Abhay'), np.int64(12)),
#  (np.int64(48), np.str_('Teclov'), np.int64(13)),
#  (np.int64(40), np.str_('Ankit'), np.int64(11)),
#  (np.int64(35), np.str_('Ankit'), np.int64(11)),
#  (np.int64(73), np.str_('Teclov'), np.int64(10))]

# %%
df = pd.DataFrame(data = a,columns=['temp','name','random'])
df
# Out:
#     temp      name  random
# 0     28     Ankit      12
# 1     43     Ankit      10
# 2     67  Geekshub      14
# 3     76     Abhay      11
# 4     80  Geekshub      10
# 5     91     Abhay      12
# 6     90  Geekshub      12
# 7     61     Abhay      10
# 8     71     Abhay      14
# 9     29     Ankit      13
# 10    40     Abhay      11
# 11    66    Teclov      10
# 12    91     Abhay      10
# 13    90     Abhay      10
# 14    46  Geekshub      13
# 15    41     Abhay      12
# 16    48    Teclov      13
# 17    40     Ankit      11
# 18    35     Ankit      11
# 19    73    Teclov      10

# %%
df[['temp','name']].values
# Out:
# array([[28, np.str_('Ankit')],
#        [43, np.str_('Ankit')],
#        [67, np.str_('Geekshub')],
#        [76, np.str_('Abhay')],
#        [80, np.str_('Geekshub')],
#        [91, np.str_('Abhay')],
#        [90, np.str_('Geekshub')],
#        [61, np.str_('Abhay')],
#        [71, np.str_('Abhay')],
#        [29, np.str_('Ankit')],
#        [40, np.str_('Abhay')],
#        [66, np.str_('Teclov')],
#        [91, np.str_('Abhay')],
#        [90, np.str_('Abhay')],
#        [46, np.str_('Geekshub')],
#        [41, np.str_('Abhay')],
#        [48, np.str_('Teclov')],
#        [40, np.str_('Ankit')],
#        [35, np.str_('Ankit')],
#        [73, np.str_('Teclov')]], dtype=object)

# %%
temp = np.random.randint(low = 20, high =100, size = [20,])
name = np.random.choice(['Abhay','Teclov','Geekshub','Ankit'],20)
random = np.random.choice([10,11,13,12,14],20)

# %%
df = pd.DataFrame({'temp':temp, 'name':name, 'random':random})
df[:5]
# Out:
#    temp      name  random
# 0    59  Geekshub      10
# 1    84    Teclov      12
# 2    50     Ankit      13
# 3    50     Ankit      13
# 4    22    Teclov      11

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head(3)
# Out:
#    temp      name  random
# 0    59  Geekshub      10
# 1    84    Teclov      12
# 2    50     Ankit      13

# %%
df.tail(3)
# Out:
#     temp      name  random
# 17    80     Abhay      13
# 18    32  Geekshub      10
# 19    86     Abhay      12

# %%
df.shape
# Out:
# (20, 3)

# %%
df.values
# Out:
# array([[60, 'Ankit', 13],
#        [22, 'Geekshub', 10],
#        [38, 'Abhay', 14],
#        [84, 'Ankit', 12],
#        [82, 'Ankit', 13],
#        [45, 'Geekshub', 14],
#        [32, 'Abhay', 11],
#        [71, 'Geekshub', 10],
#        [61, 'Ankit', 14],
#        [29, 'Ankit', 14],
#        [41, 'Ankit', 12],
#        [36, 'Abhay', 12],
#        [50, 'Abhay', 10],
#        [37, 'Geekshub', 11],
#        [59, 'Ankit', 12],
#        [38, 'Geekshub', 14],
#        [56, 'Geekshub', 11],
#        [39, 'Teclov', 12],
#        [74, 'Teclov', 10],
#        [73, 'Ankit', 11]], dtype=object)

# %%
df.name
# Out:
# 0     Geekshub
# 1       Teclov
# 2        Ankit
# 3        Ankit
# 4       Teclov
# 5     Geekshub
# 6     Geekshub
# 7        Ankit
# 8     Geekshub
# 9        Ankit
# 10      Teclov
# 11    Geekshub
# 12    Geekshub
# 13    Geekshub
# 14    Geekshub
# 15      Teclov
# 16    Geekshub
# 17       Abhay
# 18    Geekshub
# 19       Abhay
# Name: name, dtype: object

# %%
df['name']
# Out:
# 0       Teclov
# 1        Ankit
# 2       Teclov
# 3       Teclov
# 4     Geekshub
# 5     Geekshub
# 6        Abhay
# 7     Geekshub
# 8     Geekshub
# 9     Geekshub
# 10       Ankit
# 11       Abhay
# 12      Teclov
# 13       Ankit
# 14      Teclov
# 15       Ankit
# 16       Abhay
# 17       Ankit
# 18      Teclov
# 19    Geekshub
# Name: name, dtype: object

# %%
df["temp"].describe()
# Out:
# count    20.000000
# mean     57.900000
# std      21.479243
# min      22.000000
# 25%      43.500000
# 50%      54.000000
# 75%      80.000000
# max      97.000000
# Name: temp, dtype: float64

# %%
df[['temp','random']].describe()
# Out:
#             temp     random
# count  20.000000  20.000000
# mean   57.900000  12.000000
# std    21.479243   1.169795
# min    22.000000  10.000000
# 25%    43.500000  11.000000
# 50%    54.000000  12.000000
# 75%    80.000000  13.000000
# max    97.000000  14.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   temp    20 non-null     int64
#  1   name    20 non-null     object
#  2   random  20 non-null     int64
# dtypes: int64(2), object(1)
# memory usage: 612.0+ bytes

# %%
df['name'].value_counts()
# Out:
# name
# Geekshub    10
# Teclov       4
# Ankit        4
# Abhay        2
# Name: count, dtype: int64

# %%
df
# Out:
#     temp      name  random
# 0     59  Geekshub      10
# 1     84    Teclov      12
# 2     50     Ankit      13
# 3     50     Ankit      13
# 4     22    Teclov      11
# 5     45  Geekshub      11
# 6     58  Geekshub      12
# 7     69     Ankit      10
# 8     64  Geekshub      13
# 9     97     Ankit      13
# 10    42    Teclov      13
# 11    38  Geekshub      12
# 12    82  Geekshub      14
# 13    80  Geekshub      12
# 14    44  Geekshub      12
# 15    47    Teclov      11
# 16    29  Geekshub      13
# 17    80     Abhay      13
# 18    32  Geekshub      10
# 19    86     Abhay      12

# %%
df.set_index('temp',inplace=True)

# %%
df
# Out:
#           name  random
# temp
# 59    Geekshub      10
# 84      Teclov      12
# 50       Ankit      13
# 50       Ankit      13
# 22      Teclov      11
# 45    Geekshub      11
# 58    Geekshub      12
# 69       Ankit      10
# 64    Geekshub      13
# 97       Ankit      13
# 42      Teclov      13
# 38    Geekshub      12
# 82    Geekshub      14
# 80    Geekshub      12
# 44    Geekshub      12
# 47      Teclov      11
# 29    Geekshub      13
# 80       Abhay      13
# 32    Geekshub      10
# 86       Abhay      12

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#     temp      name  random
# 0     59  Geekshub      10
# 1     84    Teclov      12
# 2     50     Ankit      13
# 3     50     Ankit      13
# 4     22    Teclov      11
# 5     45  Geekshub      11
# 6     58  Geekshub      12
# 7     69     Ankit      10
# 8     64  Geekshub      13
# 9     97     Ankit      13
# 10    42    Teclov      13
# 11    38  Geekshub      12
# 12    82  Geekshub      14
# 13    80  Geekshub      12
# 14    44  Geekshub      12
# 15    47    Teclov      11
# 16    29  Geekshub      13
# 17    80     Abhay      13
# 18    32  Geekshub      10
# 19    86     Abhay      12

# %%
df.set_index("temp",inplace=True)

# %%
df
# Out:
#           name  random
# temp
# 59    Geekshub      10
# 84      Teclov      12
# 50       Ankit      13
# 50       Ankit      13
# 22      Teclov      11
# 45    Geekshub      11
# 58    Geekshub      12
# 69       Ankit      10
# 64    Geekshub      13
# 97       Ankit      13
# 42      Teclov      13
# 38    Geekshub      12
# 82    Geekshub      14
# 80    Geekshub      12
# 44    Geekshub      12
# 47      Teclov      11
# 29    Geekshub      13
# 80       Abhay      13
# 32    Geekshub      10
# 86       Abhay      12

# %%
df.sort_index(axis =0, ascending=False)
# Out:
#           name  random
# temp
# 97       Ankit      13
# 86       Abhay      12
# 84      Teclov      12
# 82    Geekshub      14
# 80    Geekshub      12
# 80       Abhay      13
# 69       Ankit      10
# 64    Geekshub      13
# 59    Geekshub      10
# 58    Geekshub      12
# 50       Ankit      13
# 50       Ankit      13
# 47      Teclov      11
# 45    Geekshub      11
# 44    Geekshub      12
# 42      Teclov      13
# 38    Geekshub      12
# 32    Geekshub      10
# 29    Geekshub      13
# 22      Teclov      11

# %%
df.values
# Out:
# array([['Geekshub', 10],
#        ['Teclov', 12],
#        ['Ankit', 13],
#        ['Ankit', 13],
#        ['Teclov', 11],
#        ['Geekshub', 11],
#        ['Geekshub', 12],
#        ['Ankit', 10],
#        ['Geekshub', 13],
#        ['Ankit', 13],
#        ['Teclov', 13],
#        ['Geekshub', 12],
#        ['Geekshub', 14],
#        ['Geekshub', 12],
#        ['Geekshub', 12],
#        ['Teclov', 11],
#        ['Geekshub', 13],
#        ['Abhay', 13],
#        ['Geekshub', 10],
#        ['Abhay', 12]], dtype=object)

# %%
df.sort_values(by ='random', ascending = False)
# Out:
#           name  random
# temp
# 54       Abhay      14
# 93       Ankit      14
# 34       Abhay      14
# 21    Geekshub      13
# 90      Teclov      13
# 46    Geekshub      13
# 54    Geekshub      13
# 86       Abhay      13
# 86    Geekshub      12
# 32       Abhay      12
# 24       Ankit      12
# 56      Teclov      12
# 48      Teclov      12
# 80       Abhay      11
# 81       Ankit      11
# 71      Teclov      11
# 87      Teclov      11
# 82    Geekshub      10
# 67       Abhay      10
# 23      Teclov      10

# %%
df.drop(['random'], axis =1)
# Out:
#           name
# temp
# 23      Teclov
# 80       Abhay
# 67       Abhay
# 90      Teclov
# 87      Teclov
# 46    Geekshub
# 71      Teclov
# 82    Geekshub
# 81       Ankit
# 34       Abhay
# 48      Teclov
# 86       Abhay
# 21    Geekshub
# 56      Teclov
# 24       Ankit
# 54    Geekshub
# 93       Ankit
# 32       Abhay
# 86    Geekshub
# 54       Abhay

# %%
df.head()
# Out:
#           name  random
# temp
# 59    Geekshub      10
# 84      Teclov      12
# 50       Ankit      13
# 50       Ankit      13
# 22      Teclov      11

# %%
df.iloc[[0,2]]
# Out:
#           name  random
# temp
# 59    Geekshub      10
# 50       Ankit      13

# %%
df.iloc[1:3,1] #iloc[start:last-1:step,start:last-1,step] always use its own indexing system to rows and columns.
# Out:
# temp
# 84    12
# 50    13
# Name: random, dtype: int64

# %%
df.iloc[[True,True,False,True]]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-64-350ce628cd7f> in <cell line: 1>()
# ----> 1 df.iloc[[True,True,False,True]]
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#     965
#     966             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 967             return self._getitem_axis(maybe_callable, axis=axis)
#     968
#     969     def _is_scalar_access(self, key: tuple):
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1508         if com.is_bool_indexer(key):
#    1509             self._validate_key(key, axis)
# -> 1510             return self._getbool_axis(key, axis=axis)
#    1511
#    1512         # a list of integers
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/indexing.py in _getbool_axis(self, key, axis)
#     982         # caller is responsible for ensuring non-None axis
#     983         labels = self.obj._get_axis(axis)
# --> 984         key = check_bool_indexer(labels, key)
#     985         inds = key.nonzero()[0]
#     986         return self.obj._take_with_is_copy(inds, axis=axis)
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/indexing.py in check_bool_indexer(index, key)
#    2399         # key may contain nan elements, check_array_indexer needs bool array
#    2400         result = pd_array(result, dtype=bool)
# -> 2401     return check_array_indexer(index, result)
#    2402
#    2403
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/indexers/utils.py in check_array_indexer(array, indexer)
#     577         # GH26658
#     578         if len(indexer) != len(array):
# --> 579             raise IndexError(
#     580                 f"Boolean index has wrong length: "
#     581                 f"{len(indexer)} instead of {len(array)}"
#
# IndexError: Boolean index has wrong length: 4 instead of 20

# %%
df.head()
# Out:
#           name  random
# temp
# 59    Geekshub      10
# 84      Teclov      12
# 50       Ankit      13
# 50       Ankit      13
# 22      Teclov      11

# %%
df.loc[84:50,:]
# Out:
#         name  random
# temp
# 84    Teclov      12
# 50     Ankit      13
# 50     Ankit      13

# %%
df.loc[[84,50,22]]
# Out:
#         name  random
# temp
# 84    Teclov      12
# 50     Ankit      13
# 50     Ankit      13
# 22    Teclov      11

# %%
df.loc[[50,22],'name':'random']
# Out:
#         name  random
# temp
# 50     Ankit      13
# 50     Ankit      13
# 22    Teclov      11

# %%
df.loc[[True, True, False, True]]
# Out:
#         name  random
# temp
# 39    Teclov      13
# 84     Ankit      10
# 53    Teclov      11

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#     temp      name  random
# 0     59  Geekshub      10
# 1     84    Teclov      12
# 2     50     Ankit      13
# 3     50     Ankit      13
# 4     22    Teclov      11
# 5     45  Geekshub      11
# 6     58  Geekshub      12
# 7     69     Ankit      10
# 8     64  Geekshub      13
# 9     97     Ankit      13
# 10    42    Teclov      13
# 11    38  Geekshub      12
# 12    82  Geekshub      14
# 13    80  Geekshub      12
# 14    44  Geekshub      12
# 15    47    Teclov      11
# 16    29  Geekshub      13
# 17    80     Abhay      13
# 18    32  Geekshub      10
# 19    86     Abhay      12

# %%
df[df["name"]=="Geekshub"][["temp","random"]]
# Out:
#     temp  random
# 0     59      10
# 5     45      11
# 6     58      12
# 8     64      13
# 11    38      12
# 12    82      14
# 13    80      12
# 14    44      12
# 16    29      13
# 18    32      10

# %%
df.loc[(df.random > 13) | (df.random == 10),:]
# Out:
#     temp      name  random
# 0     59  Geekshub      10
# 7     69     Ankit      10
# 12    82  Geekshub      14
# 18    32  Geekshub      10

# %%
# Merging & concat
d1 = pd.DataFrame([['a', 1], ['b', 2]],columns=['col1', 'number'])
d2 = pd.DataFrame([['c', 3, 'lion'], ['d', 4, 'tiger']],columns=['letter', 'number', 'animal'])

# %%
d1
# Out:
#   col1  number
# 0    a       1
# 1    b       2

# %%
d2
# Out:
#   letter  number animal
# 0      c       3   lion
# 1      d       4  tiger

# %%
pd.concat([d1,d2],axis =0,ignore_index=True)
# Out:
#   col1  number letter animal
# 0    a       1    NaN    NaN
# 1    b       2    NaN    NaN
# 2  NaN       3      c   lion
# 3  NaN       4      d  tiger

# %%
pd.concat([d1,d2],axis=1)
# Out:
#   col1  number letter  number animal
# 0    a       1      c       3   lion
# 1    b       2      d       4  tiger

# %%
pd.concat([d1,d2], axis =0, ignore_index=True)
# Out:
#   animal col1 letter  number
# 0    NaN    a    NaN       1
# 1    NaN    b    NaN       2
# 2   lion  NaN      c       3
# 3  tiger  NaN      d       4

# %%
pd.concat([d2,d1], axis = 1)
# Out:
#   letter  number animal     city  temperature
# 0      c     3.0   lion  lucknow           32
# 1      d     4.0  tiger   kanpur           45
# 2    NaN     NaN    NaN     agra           30
# 3    NaN     NaN    NaN    delhi           40

# %%
d1 = pd.DataFrame({
    "city" : ["lucknow","kanpur","agra","delhi"],
    "temperature" : [32,45,30,40]
})

# %%
d1
# Out:
#       city  temperature
# 0  lucknow           32
# 1   kanpur           45
# 2     agra           30
# 3    delhi           40

# %%
d2 = pd.DataFrame({
    "city" : ["delhi","lucknow","kanpur"],
    "humidity" : [68,65,75]
})

# %%
d2
# Out:
#       city  humidity
# 0    delhi        68
# 1  lucknow        65
# 2   kanpur        75

# %%
df = pd.merge(d1,d2, on='city',how='right')

# %%
df
# Out:
#       city  temperature  humidity
# 0    delhi           40        68
# 1  lucknow           32        65
# 2   kanpur           45        75

# %%
pd.merge(d1,d2, on=['city'], how ='outer')
# Out:
#       city  temperature  humidity
# 0     agra           30       NaN
# 1    delhi           40      68.0
# 2   kanpur           45      75.0
# 3  lucknow           32      65.0

# %%
pd.merge(d1, d2, on =['city'], how='left')
# Out:
#       city  temperature  humidity
# 0  lucknow           32      65.0
# 1   kanpur           45      75.0
# 2     agra           30       NaN
# 3    delhi           40      68.0

# %%
# dataset from https://github.com/codebasics/py/blob/master/pandas/6_handling_missing_data_replace/weather_data.csv

# %%
df1 = pd.read_csv("weather_data.csv")  #/content/weather.csv

# %%
df1
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017       -99999          7  Sunny
# 2  1/3/2017           28     -99999   Snow
# 3  1/4/2017       -99999          7      0
# 4  1/5/2017           32     -99999   Rain
# 5  1/6/2017           31          2  Sunny
# 6  1/6/2017           34          5      0

# %%
# pip3 install openpyxl
df1.to_excel('df_xl.xlsx', sheet_name = 'weather_data')

# %%
# pip3 install xlrd
df2 = pd.read_excel('df_xl.xlsx')

# %%
df2
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %%
df2.to_csv('file.csv')

# %%
df2.to_csv('file_noindex.csv', index = False)

# %%
df_group = df2.groupby("event")

# %%
df_group

# %%
for temperature in df_group:
    print(temperature)
# Out:
# ('Rain',         day  temperature  windspeed event
# 0  1/1/2017           32          6  Rain
# 4  1/5/2017           32          4  Rain)
# ('Snow',         day  temperature  windspeed event
# 2  1/3/2017           28          2  Snow
# 3  1/4/2017           24          7  Snow)
# ('Sunny',         day  temperature  windspeed  event
# 1  1/2/2017           35          7  Sunny
# 5  1/6/2017           31          2  Sunny)

# %%
df_group.get_group('Rain')
# Out:
#         day  temperature  windspeed event
# 0  1/1/2017           32          6  Rain
# 4  1/5/2017           32          4  Rain

# %%
df_group.describe()
# Out:
#       temperature                                               windspeed  \
#             count  mean       std   min   25%   50%   75%   max     count
# event
# Rain          2.0  32.0  0.000000  32.0  32.0  32.0  32.0  32.0       2.0
# Snow          2.0  26.0  2.828427  24.0  25.0  26.0  27.0  28.0       2.0
# Sunny         2.0  33.0  2.828427  31.0  32.0  33.0  34.0  35.0       2.0
#
#
#       mean       std  min   25%  50%   75%  max
# event
# Rain   5.0  1.414214  4.0  4.50  5.0  5.50  6.0
# Snow   4.5  3.535534  2.0  3.25  4.5  5.75  7.0
# Sunny  4.5  3.535534  2.0  3.25  4.5  5.75  7.0

# %%
def hot_temp(x):
    return x > 30

# %%
df2['hot_temp'] = df2['temperature'].apply(hot_temp)

# %%
df2
# Out:
#         day  temperature  windspeed  event  hot_temp
# 0  1/1/2017           32          6   Rain      True
# 1  1/2/2017           35          7  Sunny      True
# 2  1/3/2017           28          2   Snow     False
# 3  1/4/2017           24          7   Snow     False
# 4  1/5/2017           32          4   Rain      True
# 5  1/6/2017           31          2  Sunny      True

# %%
df2['hot_temp'] = df2['temperature'].apply(lambda x: x > 30)

# %%
df2
# Out:
#         day  temperature  windspeed  event  hot_temp
# 0  1/1/2017           32          6   Rain      True
# 1  1/2/2017           35          7  Sunny      True
# 2  1/3/2017           28          2   Snow     False
# 3  1/4/2017           24          7   Snow     False
# 4  1/5/2017           32          4   Rain      True
# 5  1/6/2017           31          2  Sunny      True

# %%
#pivot table

# %%
df2.pivot_table(values = 'temperature', index = 'event', aggfunc = 'mean')
# Out:
#        temperature
# event
# Rain            32
# Snow            26
# Sunny           33

# %%
df2.pivot_table(columns = 'temperature')
# Out:
# temperature     24     28    31    32    35
# hot_temp     False  False  True  True  True
# windspeed        7      2     2     5     7

# %%
help(pd.DataFrame.pivot_table)
# Out:
# Help on function pivot_table in module pandas.core.frame:
#
# pivot_table(self, values=None, index=None, columns=None, aggfunc='mean', fill_value=None, margins=False, dropna=True, margins_name='All')
#     Create a spreadsheet-style pivot table as a DataFrame. The levels in
#     the pivot table will be stored in MultiIndex objects (hierarchical
#     indexes) on the index and columns of the result DataFrame
#
#     Parameters
#     ----------
#     values : column to aggregate, optional
#     index : column, Grouper, array, or list of the previous
#         If an array is passed, it must be the same length as the data. The
#         list can contain any of the other types (except list).
#         Keys to group by on the pivot table index.  If an array is passed,
#         it is being used as the same manner as column values.
#     columns : column, Grouper, array, or list of the previous
#         If an array is passed, it must be the same length as the data. The
#         list can contain any of the other types (except list).
#         Keys to group by on the pivot table column.  If an array is passed,
#         it is being used as the same manner as column values.
#     aggfunc : function or list of functions, default numpy.mean
#         If list of functions passed, the resulting pivot table will have
#         hierarchical columns whose top level are the function names
#         (inferred from the function objects themselves)
#     fill_value : scalar, default None
#         Value to replace missing values with
#     margins : boolean, default False
#         Add all row / columns (e.g. for subtotal / grand totals)
#     dropna : boolean, default True
#         Do not include columns whose entries are all NaN
#     margins_name : string, default 'All'
#         Name of the row / column that will contain the totals
#         when margins is True.
#
#     Examples
#     --------
#     >>> df = pd.DataFrame({"A": ["foo", "foo", "foo", "foo", "foo",
#     ...                          "bar", "bar", "bar", "bar"],
#     ...                    "B": ["one", "one", "one", "two", "two",
#     ...                          "one", "one", "two", "two"],
#     ...                    "C": ["small", "large", "large", "small",
#     ...                          "small", "large", "small", "small",
#     ...                          "large"],
#     ...                    "D": [1, 2, 2, 3, 3, 4, 5, 6, 7]})
#     >>> df
#          A    B      C  D
#     0  foo  one  small  1
#     1  foo  one  large  2
#     2  foo  one  large  2
#     3  foo  two  small  3
#     4  foo  two  small  3
#     5  bar  one  large  4
#     6  bar  one  small  5
#     7  bar  two  small  6
#     8  bar  two  large  7
#
#     >>> table = pivot_table(df, values='D', index=['A', 'B'],
#     ...                     columns=['C'], aggfunc=np.sum)
#     >>> table
#     ... # doctest: +NORMALIZE_WHITESPACE
#     C        large  small
#     A   B
#     bar one    4.0    5.0
#         two    7.0    6.0
#     foo one    4.0    1.0
#         two    NaN    6.0
#
#     Returns
#     -------
#     table : DataFrame
#
#     See also
#     --------
#     DataFrame.pivot : pivot without aggregation that can handle
#         non-numeric data

# %% [markdown]
# ##### groupby

# %%
import pandas as pd
df=pd.read_csv("/content/weather_by_cities.csv")
df
# Out:
#          day      city  temperature  windspeed   event
# 0   1/1/2017  new york           32          6    Rain
# 1   1/2/2017  new york           36          7   Sunny
# 2   1/3/2017  new york           28         12    Snow
# 3   1/4/2017  new york           33          7   Sunny
# 4   1/1/2017    mumbai           90          5   Sunny
# 5   1/2/2017    mumbai           85         12     Fog
# 6   1/3/2017    mumbai           87         15     Fog
# 7   1/4/2017    mumbai           92          5    Rain
# 8   1/1/2017     paris           45         20   Sunny
# 9   1/2/2017     paris           50         13  Cloudy
# 10  1/3/2017     paris           54          8  Cloudy
# 11  1/4/2017     paris           42         10  Cloudy

# %%
g=df.groupby("city")

# %%
g.get_group("mumbai")["temperature"].max()
# Out:
# 92

# %%
g
